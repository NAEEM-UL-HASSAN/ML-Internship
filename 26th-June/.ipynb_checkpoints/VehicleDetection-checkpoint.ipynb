# %%
'Vehicle Detection using Yolov8 Model'
import gradio as gr
from gradio.components import Video
import cv2
import numpy as np
from collections import defaultdict
from ultralytics import YOLO
import supervision as sv

# %%
def vehicles_detection(video_path):
    """
    Detect and classify vehicles in a video using YOLOv8 model.

    Parameters
    ----------
    video_path : str
        Path to the input video file.

    Returns
    -------
    None
    """
    # Load the YOLOv8 model
    model = YOLO('yolov8n.pt')
    cap = cv2.VideoCapture(video_path)
    
    # Define the line coordinates
    start = sv.Point(182, 254)
    end = sv.Point(462, 254)
    
    # Store the track history
    track_history = defaultdict(list)
    # Create a dictionary to keep track of objects that have crossed the line
    crossed_objects = {}
    
    # Open a video sink for the output video
    video_info = sv.VideoInfo.from_video_path(video_path)
    with sv.VideoSink("output_video.mp4", video_info) as sink:
        while cap.isOpened():
            success, frame = cap.read()
            if not success:
                break
            
            # Run YOLOv8 tracking on the frame, persisting tracks between frames
            results = model.track(
                frame,
                classes=[2, 3, 5, 7],
                persist=True,
                save=True,
                tracker="bytetrack.yaml"
            )

            # Get the boxes and track IDs
            boxes = results[0].boxes.xywh.cpu()
            track_ids = results[0].boxes.id.int().cpu().tolist()

            # Visualize the results on the frame
            annotated_frame = results[0].plot()
            detections = sv.Detections.from_yolov8(results[0])

            # Plot the tracks and count objects crossing the line
            for box, track_id in zip(boxes, track_ids):
                x, y, w, h = box
                track = track_history[track_id]
                track.append((float(x), float(y)))  # x, y center point
                if len(track) > 30:  # retain 30 tracks for 30 frames
                    track.pop(0)

                # Check if the object crosses the line
                if start.x < x < end.x and abs(y - start.y) < 5:  # Assuming objects cross horizontally
                    if track_id not in crossed_objects:
                        crossed_objects[track_id] = True

                    # Annotate the object as it crosses the line
                    cv2.rectangle(
                        annotated_frame,
                        (int(x - w / 2), int(y - h / 2)),
                        (int(x + w / 2), int(y + h / 2)),
                        (0, 255, 0),
                        2
                    )

            # Draw the line on the frame
            cv2.line(annotated_frame, (start.x, start.y), (end.x, end.y), (0, 255, 0), 2)

            # Write the count of objects on each frame
            count_text = f"Vehicles Crossed: {len(crossed_objects)}"
            cv2.putText(annotated_frame, count_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

            # Write the frame with annotations to the output video
            sink.write_frame(annotated_frame)

    # Release the video capture
    cap.release()

# %%
# Create Gradio interface
iface = gr.Interface(
    fn=vehicles_detection,
    inputs=Video(),  # Use Video component from gradio.components
    outputs=Video(), # Use Video component from gradio.components
    title="Vehicle Detection and Classification",
    description="Upload a video to detect and classify vehicles using YOLOv8."
)

# %%
if __name__ == "__main__":
    iface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 0: 384x640 7 cars, 208.7ms
# Speed: 6.0ms preprocess, 208.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 209.8ms
# Speed: 5.0ms preprocess, 209.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 204.9ms
# Speed: 4.1ms preprocess, 204.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 232.2ms
# Speed: 4.1ms preprocess, 232.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 205.4ms
# Speed: 7.0ms preprocess, 205.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 209.3ms
# Speed: 7.0ms preprocess, 209.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 225.6ms
# Speed: 9.0ms preprocess, 225.6ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 378.9ms
# Speed: 14.1ms preprocess, 378.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 313.2ms
# Speed: 4.8ms preprocess, 313.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 294.6ms
# Speed: 4.8ms preprocess, 294.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 322.5ms
# Speed: 6.0ms preprocess, 322.5ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 274.5ms
# Speed: 6.9ms preprocess, 274.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 240.3ms
# Speed: 10.0ms preprocess, 240.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 235.8ms
# Speed: 4.1ms preprocess, 235.8ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 264.9ms
# Speed: 14.4ms preprocess, 264.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 212.9ms
# Speed: 11.0ms preprocess, 212.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 263.8ms
# Speed: 4.0ms preprocess, 263.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 249.5ms
# Speed: 10.0ms preprocess, 249.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 219.1ms
# Speed: 4.0ms preprocess, 219.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 250.8ms
# Speed: 4.0ms preprocess, 250.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 220.9ms
# Speed: 4.8ms preprocess, 220.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 241.0ms
# Speed: 2.0ms preprocess, 241.0ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 275.5ms
# Speed: 5.6ms preprocess, 275.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 225.3ms
# Speed: 6.1ms preprocess, 225.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 221.3ms
# Speed: 5.6ms preprocess, 221.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 264.6ms
# Speed: 5.0ms preprocess, 264.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 238.1ms
# Speed: 4.9ms preprocess, 238.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 251.8ms
# Speed: 6.0ms preprocess, 251.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 269.0ms
# Speed: 5.0ms preprocess, 269.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 213.3ms
# Speed: 4.0ms preprocess, 213.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 240.5ms
# Speed: 7.5ms preprocess, 240.5ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 352.6ms
# Speed: 4.0ms preprocess, 352.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 251.3ms
# Speed: 17.0ms preprocess, 251.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 250.0ms
# Speed: 4.0ms preprocess, 250.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 258.3ms
# Speed: 3.0ms preprocess, 258.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 218.3ms
# Speed: 4.1ms preprocess, 218.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 205.0ms
# Speed: 5.0ms preprocess, 205.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 312.3ms
# Speed: 4.0ms preprocess, 312.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 235.2ms
# Speed: 4.0ms preprocess, 235.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 202.0ms
# Speed: 4.2ms preprocess, 202.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 218.1ms
# Speed: 6.0ms preprocess, 218.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 211.4ms
# Speed: 3.0ms preprocess, 211.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 204.8ms
# Speed: 5.5ms preprocess, 204.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 215.5ms
# Speed: 2.0ms preprocess, 215.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 215.6ms
# Speed: 7.0ms preprocess, 215.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 203.1ms
# Speed: 3.0ms preprocess, 203.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 215.4ms
# Speed: 3.2ms preprocess, 215.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 235.6ms
# Speed: 3.0ms preprocess, 235.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 202.3ms
# Speed: 4.0ms preprocess, 202.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 206.8ms
# Speed: 3.0ms preprocess, 206.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 207.4ms
# Speed: 3.2ms preprocess, 207.4ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 200.9ms
# Speed: 3.2ms preprocess, 200.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 9 cars, 204.3ms
# Speed: 3.2ms preprocess, 204.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 9 cars, 209.1ms
# Speed: 5.0ms preprocess, 209.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 9 cars, 197.7ms
# Speed: 3.0ms preprocess, 197.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 9 cars, 207.3ms
# Speed: 3.2ms preprocess, 207.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 9 cars, 227.0ms
# Speed: 4.0ms preprocess, 227.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 9 cars, 204.1ms
# Speed: 4.0ms preprocess, 204.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 9 cars, 203.2ms
# Speed: 4.0ms preprocess, 203.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 9 cars, 235.6ms
# Speed: 4.2ms preprocess, 235.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 9 cars, 208.5ms
# Speed: 6.0ms preprocess, 208.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 196.5ms
# Speed: 2.2ms preprocess, 196.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 210.4ms
# Speed: 4.2ms preprocess, 210.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 205.6ms
# Speed: 2.0ms preprocess, 205.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 204.3ms
# Speed: 3.0ms preprocess, 204.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 209.3ms
# Speed: 3.0ms preprocess, 209.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 205.6ms
# Speed: 3.2ms preprocess, 205.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 8 cars, 201.4ms
# Speed: 3.0ms preprocess, 201.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 7 cars, 212.9ms
# Speed: 4.0ms preprocess, 212.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 209.1ms
# Speed: 4.0ms preprocess, 209.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 197.2ms
# Speed: 3.2ms preprocess, 197.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 223.1ms
# Speed: 3.0ms preprocess, 223.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 211.5ms
# Speed: 2.2ms preprocess, 211.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 199.1ms
# Speed: 2.9ms preprocess, 199.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 204.4ms
# Speed: 3.3ms preprocess, 204.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 213.1ms
# Speed: 4.2ms preprocess, 213.1ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 202.6ms
# Speed: 5.9ms preprocess, 202.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 202.9ms
# Speed: 3.0ms preprocess, 202.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 231.5ms
# Speed: 3.0ms preprocess, 231.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 207.9ms
# Speed: 3.1ms preprocess, 207.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 199.1ms
# Speed: 4.0ms preprocess, 199.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 217.5ms
# Speed: 3.0ms preprocess, 217.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 204.5ms
# Speed: 4.1ms preprocess, 204.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 199.7ms
# Speed: 6.0ms preprocess, 199.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 235.2ms
# Speed: 7.0ms preprocess, 235.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 209.4ms
# Speed: 4.0ms preprocess, 209.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 197.5ms
# Speed: 3.0ms preprocess, 197.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 220.4ms
# Speed: 3.0ms preprocess, 220.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 208.0ms
# Speed: 3.0ms preprocess, 208.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 203.3ms
# Speed: 3.0ms preprocess, 203.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 202.3ms
# Speed: 2.1ms preprocess, 202.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 214.7ms
# Speed: 2.1ms preprocess, 214.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 201.9ms
# Speed: 4.0ms preprocess, 201.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 204.2ms
# Speed: 3.2ms preprocess, 204.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 223.9ms
# Speed: 3.0ms preprocess, 223.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 206.2ms
# Speed: 6.4ms preprocess, 206.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 204.5ms
# Speed: 6.0ms preprocess, 204.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 215.3ms
# Speed: 3.0ms preprocess, 215.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 197.9ms
# Speed: 3.2ms preprocess, 197.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 202.2ms
# Speed: 2.4ms preprocess, 202.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 206.8ms
# Speed: 3.1ms preprocess, 206.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 211.3ms
# Speed: 7.0ms preprocess, 211.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 202.8ms
# Speed: 4.0ms preprocess, 202.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 211.2ms
# Speed: 4.0ms preprocess, 211.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 206.1ms
# Speed: 3.1ms preprocess, 206.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 200.6ms
# Speed: 4.0ms preprocess, 200.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 208.1ms
# Speed: 4.0ms preprocess, 208.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 207.2ms
# Speed: 2.1ms preprocess, 207.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 200.2ms
# Speed: 3.1ms preprocess, 200.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 199.5ms
# Speed: 3.3ms preprocess, 199.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 208.8ms
# Speed: 2.2ms preprocess, 208.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 201.7ms
# Speed: 5.0ms preprocess, 201.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 199.0ms
# Speed: 4.0ms preprocess, 199.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 212.0ms
# Speed: 6.0ms preprocess, 212.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 205.8ms
# Speed: 3.2ms preprocess, 205.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 215.2ms
# Speed: 4.0ms preprocess, 215.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 212.2ms
# Speed: 3.1ms preprocess, 212.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 208.2ms
# Speed: 3.2ms preprocess, 208.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 200.2ms
# Speed: 7.2ms preprocess, 200.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 210.3ms
# Speed: 3.2ms preprocess, 210.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 208.3ms
# Speed: 3.3ms preprocess, 208.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 203.5ms
# Speed: 3.0ms preprocess, 203.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 210.0ms
# Speed: 3.0ms preprocess, 210.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 206.3ms
# Speed: 3.3ms preprocess, 206.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 210.0ms
# Speed: 6.0ms preprocess, 210.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 205.0ms
# Speed: 2.3ms preprocess, 205.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 207.8ms
# Speed: 4.0ms preprocess, 207.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 201.4ms
# Speed: 2.0ms preprocess, 201.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 202.0ms
# Speed: 4.5ms preprocess, 202.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 215.4ms
# Speed: 3.2ms preprocess, 215.4ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 217.3ms
# Speed: 3.5ms preprocess, 217.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 194.3ms
# Speed: 3.0ms preprocess, 194.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 206.2ms
# Speed: 4.2ms preprocess, 206.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 203.6ms
# Speed: 7.1ms preprocess, 203.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 197.3ms
# Speed: 4.2ms preprocess, 197.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 216.9ms
# Speed: 3.0ms preprocess, 216.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 212.3ms
# Speed: 3.3ms preprocess, 212.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 201.3ms
# Speed: 3.0ms preprocess, 201.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 217.6ms
# Speed: 3.0ms preprocess, 217.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 210.3ms
# Speed: 3.0ms preprocess, 210.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 213.8ms
# Speed: 4.3ms preprocess, 213.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 215.0ms
# Speed: 2.0ms preprocess, 215.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 222.5ms
# Speed: 3.2ms preprocess, 222.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 201.1ms
# Speed: 5.2ms preprocess, 201.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 206.8ms
# Speed: 7.0ms preprocess, 206.8ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 216.0ms
# Speed: 2.2ms preprocess, 216.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 201.9ms
# Speed: 4.1ms preprocess, 201.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 215.8ms
# Speed: 5.1ms preprocess, 215.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 209.6ms
# Speed: 3.2ms preprocess, 209.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 203.2ms
# Speed: 2.0ms preprocess, 203.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 201.8ms
# Speed: 3.6ms preprocess, 201.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 211.0ms
# Speed: 4.1ms preprocess, 211.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 202.2ms
# Speed: 2.2ms preprocess, 202.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 196.0ms
# Speed: 3.1ms preprocess, 196.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 232.2ms
# Speed: 6.0ms preprocess, 232.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 213.5ms
# Speed: 6.0ms preprocess, 213.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 194.4ms
# Speed: 3.0ms preprocess, 194.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 212.8ms
# Speed: 2.6ms preprocess, 212.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 210.2ms
# Speed: 2.2ms preprocess, 210.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 207.1ms
# Speed: 6.0ms preprocess, 207.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 205.5ms
# Speed: 3.1ms preprocess, 205.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 274.1ms
# Speed: 3.2ms preprocess, 274.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 203.0ms
# Speed: 7.0ms preprocess, 203.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 215.6ms
# Speed: 3.0ms preprocess, 215.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 213.7ms
# Speed: 4.4ms preprocess, 213.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 203.7ms
# Speed: 5.4ms preprocess, 203.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 206.6ms
# Speed: 3.1ms preprocess, 206.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 211.0ms
# Speed: 7.0ms preprocess, 211.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 197.0ms
# Speed: 3.1ms preprocess, 197.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 211.7ms
# Speed: 2.2ms preprocess, 211.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 208.6ms
# Speed: 3.6ms preprocess, 208.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 207.8ms
# Speed: 3.1ms preprocess, 207.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 205.1ms
# Speed: 5.0ms preprocess, 205.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 214.5ms
# Speed: 3.2ms preprocess, 214.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 203.4ms
# Speed: 3.3ms preprocess, 203.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 203.7ms
# Speed: 5.2ms preprocess, 203.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 206.2ms
# Speed: 2.0ms preprocess, 206.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 210.7ms
# Speed: 3.3ms preprocess, 210.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 211.8ms
# Speed: 4.8ms preprocess, 211.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 212.8ms
# Speed: 3.0ms preprocess, 212.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 204.0ms
# Speed: 4.0ms preprocess, 204.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 203.7ms
# Speed: 5.6ms preprocess, 203.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 207.8ms
# Speed: 8.0ms preprocess, 207.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 205.9ms
# Speed: 3.2ms preprocess, 205.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 198.3ms
# Speed: 9.0ms preprocess, 198.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 237.3ms
# Speed: 3.0ms preprocess, 237.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 6 cars, 312.5ms
# Speed: 6.3ms preprocess, 312.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 284.9ms
# Speed: 3.0ms preprocess, 284.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 258.8ms
# Speed: 9.0ms preprocess, 258.8ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 249.6ms
# Speed: 4.4ms preprocess, 249.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 256.1ms
# Speed: 3.5ms preprocess, 256.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 210.4ms
# Speed: 5.5ms preprocess, 210.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 245.6ms
# Speed: 3.2ms preprocess, 245.6ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 215.9ms
# Speed: 2.4ms preprocess, 215.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 243.8ms
# Speed: 2.0ms preprocess, 243.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 218.0ms
# Speed: 3.0ms preprocess, 218.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 208.9ms
# Speed: 1.9ms preprocess, 208.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 270.4ms
# Speed: 4.0ms preprocess, 270.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 204.6ms
# Speed: 4.0ms preprocess, 204.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 205.7ms
# Speed: 3.1ms preprocess, 205.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 259.0ms
# Speed: 3.1ms preprocess, 259.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 197.0ms
# Speed: 4.9ms preprocess, 197.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 211.3ms
# Speed: 6.0ms preprocess, 211.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 238.6ms
# Speed: 3.1ms preprocess, 238.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 195.5ms
# Speed: 4.0ms preprocess, 195.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 212.6ms
# Speed: 3.2ms preprocess, 212.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 217.1ms
# Speed: 3.2ms preprocess, 217.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 200.5ms
# Speed: 3.2ms preprocess, 200.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 206.2ms
# Speed: 5.0ms preprocess, 206.2ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 212.0ms
# Speed: 3.2ms preprocess, 212.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 201.0ms
# Speed: 5.1ms preprocess, 201.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 206.0ms
# Speed: 3.5ms preprocess, 206.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 208.1ms
# Speed: 4.3ms preprocess, 208.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 202.0ms
# Speed: 4.0ms preprocess, 202.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 5 cars, 208.8ms
# Speed: 3.1ms preprocess, 208.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 4 cars, 216.0ms
# Speed: 3.9ms preprocess, 216.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 4 cars, 200.5ms
# Speed: 3.0ms preprocess, 200.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 4 cars, 204.3ms
# Speed: 3.0ms preprocess, 204.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 4 cars, 210.4ms
# Speed: 4.0ms preprocess, 210.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 4 cars, 206.9ms
# Speed: 4.0ms preprocess, 206.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 4 cars, 205.5ms
# Speed: 5.0ms preprocess, 205.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 4 cars, 210.8ms
# Speed: 2.0ms preprocess, 210.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 4 cars, 203.5ms
# Speed: 5.5ms preprocess, 203.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 4 cars, 200.0ms
# Speed: 7.1ms preprocess, 200.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 4 cars, 209.9ms
# Speed: 3.0ms preprocess, 209.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 3 cars, 1 truck, 208.4ms
# Speed: 2.2ms preprocess, 208.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 4 cars, 204.2ms
# Speed: 3.0ms preprocess, 204.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
#
# 0: 384x640 4 cars, 215.6ms
# Speed: 3.0ms preprocess, 215.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\track
